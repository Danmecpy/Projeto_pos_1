# %%
import duckdb
import pandas as pd  
import os

# %%
con = duckdb.connect(database='dados_duckdb.db', read_only=False)
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 con = duckdb.connect(database='dados_duckdb.db', read_only=False)
#
# IOException: IO Error: Cannot open file "c:\users\danme\desenvolvimento\projeto_pos_1\scripts\dados_duckdb.db": O arquivo já está sendo usado por outro processo.
#
# File is already open in
# C:\Users\danme\AppData\Local\Programs\Python\Python313\python.exe (PID 24900)
